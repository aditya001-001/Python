# %%
class BankAccount:
    def __init__(self,name,balance):
        self.name=name
        self.__balance=balance
    def deposit(self,amount):
        if amount>0:
            self.__balance+=amount
    def withdrawal(self,amount):
        if amount>0 and amount<=self.__balance:
            self.__balance-=amount
    def get_balance(self):
        return self.__balance
account=BankAccount('adi',1000)
print(account.get_balance())
account.deposit(1000)
account.withdrawal(300)
print(account.get_balance())
# Out:
# 1000
# 1700

# %%
class Student:
    def __init__(self,name,marks):
        self.name=name
        self.__marks=marks
    def get_marks(self):
        return self.__marks
    def set_marks(self,marks):
        if marks>=0 and marks<=100:
            self.__marks=marks
stu=Student('Aditya',95)
print(stu.get_marks())
stu.set_marks(89)
print(stu.get_marks())
# Out:
# 95
# 89

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.__salary=salary
    def get_salary(self):
        return self.__salary
    def set_salary(self,salary):
            if salary>0:
                self.__salary=salary
emp=Employee('Adi',50000)
print(emp.get_salary())
emp.set_salary(70000)
print(emp.get_salary())
# Out:
# 50000
# 70000

# %%
class Product():
    def __init__(self,name,price):
        self.name=name
        self.__price=price
    def set_price(self,price):
        if price>0:
            self.__price=price
    def get_price(self):
        return self.__price
product = Product("Laptop", 50000)
print(product.get_price())
product.set_price(60000)
print(product.get_price())

product.set_price(-1000)
print(product.get_price())

print(product._Product__price)
# Out:
# 50000
# 60000
# 60000
# 60000

# %%
class User:
    def __init__(self,name,password):
        self.name=name
        self.__password=password
    def get_username(self):
        return self.name
    def check_password(self,password):
        return self.__password==password

    def change_password(self,oldpass,newpass):
        if self.__password==oldpass:
            self.__password=newpass
        else:
            return False
user=User('Adi','python123')
user.get_username()
print(user.check_password('python123'))
user.change_password('python123','adi123')
print(user.check_password('python123'))
print(user.check_password('adi123'))
user.change_password('wrongpass','shadab123')
print(user.check_password('adi123'))
# Out:
# True
# False
# True
# True

# %%
class car:
    def __init__(self,brand,speed):
        self.brand=brand
        self.__speed=speed
    def accelerate(self,amount):
        if amount<=120:
            self.__speed+=amount
            if self.__speed>=120:
                self.__speed-=(self.__speed-120)

    def break(self,amount):
        self.__
